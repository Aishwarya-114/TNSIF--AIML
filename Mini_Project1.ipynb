# %% [markdown]
# <a href="https://colab.research.google.com/github/Aishwarya-114/TNSIF--AIML/blob/main/Mini_Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# List to store student names
student_names = []

# Input student details
name = input("Enter student name: ")
age = int(input("Enter age: "))
num_subjects = int(input("Enter number of subjects: "))

# Store name in list
student_names.append(name)

# Set to store subjects
subjects = set()

# Dictionary to store subject-wise marks
marks_dict = {}

# Input subject names and marks
for i in range(num_subjects):
    subject = input(f"Enter subject {i+1} name: ")
    marks = int(input(f"Enter marks for {subject}: "))
    subjects.add(subject)
    marks_dict[subject] = marks
    # Tuple to store student information
    student_info = (name, age)
    # Calculate total and average
    total_marks = sum(marks_dict.values())
    average_marks = total_marks / num_subjects

    # Display Report Card
    print("\n===== STUDENT REPORT CARD =====")
    print("Name:", student_info[0])
    print("Age:", student_info[1])
    print("Subjects:", subjects)

    print("\nMarks:")
    for subject, marks in marks_dict.items():
      print(subject, ":", marks)

      print("\nTotal Marks:", total_marks)
      print("Average Marks:", average_marks)
# Out:
# Enter student name: Aishwarya
# Enter age: 21
# Enter number of subjects: 3
# Enter subject 1 name: Machine Learning
# Enter marks for Machine Learning: 75
#
# ===== STUDENT REPORT CARD =====
# Name: Aishwarya
# Age: 21
# Subjects: {'Machine Learning'}
#
# Marks:
# Machine Learning : 75
#
# Total Marks: 75
# Average Marks: 25.0
# Enter subject 2 name: JAVA
# Enter marks for JAVA: 65
#
# ===== STUDENT REPORT CARD =====
# Name: Aishwarya
# Age: 21
# Subjects: {'Machine Learning', 'JAVA'}
#
# Marks:
# Machine Learning : 75
#
# Total Marks: 140
# Average Marks: 46.666666666666664
# JAVA : 65
#
# Total Marks: 140
# Average Marks: 46.666666666666664
# Enter subject 3 name: DBMS
# Enter marks for DBMS: 73
#
# ===== STUDENT REPORT CARD =====
# Name: Aishwarya
# Age: 21
# Subjects: {'DBMS', 'Machine Learning', 'JAVA'}
#
# Marks:
# Machine Learning : 75
#
# Total Marks: 213
# Average Marks: 71.0
# JAVA : 65
#
# Total Marks: 213
# Average Marks: 71.0
# DBMS : 73
#
# Total Marks: 213
# ...
